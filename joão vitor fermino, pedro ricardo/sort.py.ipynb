# %%
# Bubble Sort (ordem crescente)
def bubble_sort(arr):
    n = len(arr)
    print(f"\n--- Bubble Sort (Crescente) ---")
    print(f"Vetor inicial: {arr}")
    
    for i in range(n):
        for j in range(0, n - i - 1):
            if arr[j] > arr[j + 1]:
                print(f"Troca: {arr[j]} <-> {arr[j+1]}")
                arr[j], arr[j + 1] = arr[j + 1], arr[j]
                print(f"Estado atual: {arr}")
    print(f"Resultado final: {arr}")


# Insertion Sort (ordem decrescente)
def insertion_sort(arr):
    print(f"\n--- Insertion Sort (Decrescente) ---")
    print(f"Vetor inicial: {arr}")
    
    for i in range(1, len(arr)):
        chave = arr[i]
        j = i - 1
        while j >= 0 and arr[j] < chave:
            arr[j + 1] = arr[j]
            j -= 1
            print(f"Movendo elemento: {arr}")
        arr[j + 1] = chave
        print(f"Inserção da chave {chave}: {arr}")
    print(f"Resultado final: {arr}")


# -------------------------
# Testes com os vetores
# -------------------------

melhor = [1, 10, 13, 14, 29, 37]
medio = [29, 10, 14, 37, 13, 1]
pior  = [37, 29, 14, 13, 10, 1]

# Bubble Sort crescente
for caso, vetor in [("Melhor caso", melhor.copy()), 
                    ("Caso médio", medio.copy()), 
                    ("Pior caso", pior.copy())]:
    print(f"\n### {caso} ###")
    bubble_sort(vetor)

# Insertion Sort decrescente
for caso, vetor in [("Melhor caso", melhor.copy()), 
                    ("Caso médio", medio.copy()), 
                    ("Pior caso", pior.copy())]:
    print(f"\n### {caso} ###")
    insertion_sort(vetor)
# Out:
# ### Melhor caso ###
#
# --- Bubble Sort (Crescente) ---
# Vetor inicial: [1, 10, 13, 14, 29, 37]
# Resultado final: [1, 10, 13, 14, 29, 37]
#
# ### Caso médio ###
#
# --- Bubble Sort (Crescente) ---
# Vetor inicial: [29, 10, 14, 37, 13, 1]
# Troca: 29 <-> 10
# Estado atual: [10, 29, 14, 37, 13, 1]
# Troca: 29 <-> 14
# Estado atual: [10, 14, 29, 37, 13, 1]
# Troca: 37 <-> 13
# Estado atual: [10, 14, 29, 13, 37, 1]
# Troca: 37 <-> 1
# Estado atual: [10, 14, 29, 13, 1, 37]
# Troca: 29 <-> 13
# Estado atual: [10, 14, 13, 29, 1, 37]
# Troca: 29 <-> 1
# Estado atual: [10, 14, 13, 1, 29, 37]
# Troca: 14 <-> 13
# Estado atual: [10, 13, 14, 1, 29, 37]
# Troca: 14 <-> 1
# Estado atual: [10, 13, 1, 14, 29, 37]
# Troca: 13 <-> 1
# Estado atual: [10, 1, 13, 14, 29, 37]
# Troca: 10 <-> 1
# Estado atual: [1, 10, 13, 14, 29, 37]
# Resultado final: [1, 10, 13, 14, 29, 37]
#
# ### Pior caso ###
#
# --- Bubble Sort (Crescente) ---
# Vetor inicial: [37, 29, 14, 13, 10, 1]
# Troca: 37 <-> 29
# Estado atual: [29, 37, 14, 13, 10, 1]
# Troca: 37 <-> 14
# Estado atual: [29, 14, 37, 13, 10, 1]
# Troca: 37 <-> 13
# Estado atual: [29, 14, 13, 37, 10, 1]
# Troca: 37 <-> 10
# Estado atual: [29, 14, 13, 10, 37, 1]
# Troca: 37 <-> 1
# Estado atual: [29, 14, 13, 10, 1, 37]
# Troca: 29 <-> 14
# Estado atual: [14, 29, 13, 10, 1, 37]
# Troca: 29 <-> 13
# Estado atual: [14, 13, 29, 10, 1, 37]
# Troca: 29 <-> 10
# Estado atual: [14, 13, 10, 29, 1, 37]
# Troca: 29 <-> 1
# Estado atual: [14, 13, 10, 1, 29, 37]
# Troca: 14 <-> 13
# Estado atual: [13, 14, 10, 1, 29, 37]
# Troca: 14 <-> 10
# Estado atual: [13, 10, 14, 1, 29, 37]
# Troca: 14 <-> 1
# Estado atual: [13, 10, 1, 14, 29, 37]
# Troca: 13 <-> 10
# Estado atual: [10, 13, 1, 14, 29, 37]
# Troca: 13 <-> 1
# Estado atual: [10, 1, 13, 14, 29, 37]
# Troca: 10 <-> 1
# Estado atual: [1, 10, 13, 14, 29, 37]
# Resultado final: [1, 10, 13, 14, 29, 37]
#
# ### Melhor caso ###
#
# --- Insertion Sort (Decrescente) ---
# Vetor inicial: [1, 10, 13, 14, 29, 37]
# Movendo elemento: [1, 1, 13, 14, 29, 37]
# Inserção da chave 10: [10, 1, 13, 14, 29, 37]
# Movendo elemento: [10, 1, 1, 14, 29, 37]
# Movendo elemento: [10, 10, 1, 14, 29, 37]
# Inserção da chave 13: [13, 10, 1, 14, 29, 37]
# Movendo elemento: [13, 10, 1, 1, 29, 37]
# Movendo elemento: [13, 10, 10, 1, 29, 37]
# Movendo elemento: [13, 13, 10, 1, 29, 37]
# Inserção da chave 14: [14, 13, 10, 1, 29, 37]
# Movendo elemento: [14, 13, 10, 1, 1, 37]
# Movendo elemento: [14, 13, 10, 10, 1, 37]
# Movendo elemento: [14, 13, 13, 10, 1, 37]
# Movendo elemento: [14, 14, 13, 10, 1, 37]
# Inserção da chave 29: [29, 14, 13, 10, 1, 37]
# Movendo elemento: [29, 14, 13, 10, 1, 1]
# Movendo elemento: [29, 14, 13, 10, 10, 1]
# Movendo elemento: [29, 14, 13, 13, 10, 1]
# Movendo elemento: [29, 14, 14, 13, 10, 1]
# Movendo elemento: [29, 29, 14, 13, 10, 1]
# Inserção da chave 37: [37, 29, 14, 13, 10, 1]
# Resultado final: [37, 29, 14, 13, 10, 1]
#
# ### Caso médio ###
#
# --- Insertion Sort (Decrescente) ---
# Vetor inicial: [29, 10, 14, 37, 13, 1]
# Inserção da chave 10: [29, 10, 14, 37, 13, 1]
# Movendo elemento: [29, 10, 10, 37, 13, 1]
# Inserção da chave 14: [29, 14, 10, 37, 13, 1]
# Movendo elemento: [29, 14, 10, 10, 13, 1]
# Movendo elemento: [29, 14, 14, 10, 13, 1]
# Movendo elemento: [29, 29, 14, 10, 13, 1]
# Inserção da chave 37: [37, 29, 14, 10, 13, 1]
# Movendo elemento: [37, 29, 14, 10, 10, 1]
# Inserção da chave 13: [37, 29, 14, 13, 10, 1]
# Inserção da chave 1: [37, 29, 14, 13, 10, 1]
# Resultado final: [37, 29, 14, 13, 10, 1]
#
# ### Pior caso ###
#
# --- Insertion Sort (Decrescente) ---
# Vetor inicial: [37, 29, 14, 13, 10, 1]
# Inserção da chave 29: [37, 29, 14, 13, 10, 1]
# Inserção da chave 14: [37, 29, 14, 13, 10, 1]
# Inserção da chave 13: [37, 29, 14, 13, 10, 1]
# Inserção da chave 10: [37, 29, 14, 13, 10, 1]
# Inserção da chave 1: [37, 29, 14, 13, 10, 1]
# Resultado final: [37, 29, 14, 13, 10, 1]
